# %%
price_per_product = '{"Product A": 22500, "Product B": 25000,"Product C": 15600}'
price_per_product

# %%
type(price_per_product)

# %%
import json

# %%
parsed_str = json.loads(price_per_product)
parsed_str

# %%
type(parsed_str)

# %%
import pandas as pd

# %%
pd.read_json('Lending-company.json')

# %%
type(pd.read_json('Lending-company.json'))

# %%
import pandas as pd

# %%
filename = 'Lending-company.xlsx'
my_xlxs_data = pd.read_excel(filename)
my_xlxs_data

# %%
type(my_xlxs_data)

# %% [markdown]
# ## Read CSV

# %%
import pandas as pd

# %%
location_data = pd.read_csv('Lending-company.csv', usecols=['StringID', 'Location','Region'], index_col='StringID')
location_data.head()
# Out:
#              Location    Region
# StringID
# LoanID_1   Location 3  Region 2
# LoanID_2   Location 6  Region 6
# LoanID_3   Location 8  Region 3
# LoanID_4  Location 26  Region 2
# LoanID_5  Location 34  Region 3

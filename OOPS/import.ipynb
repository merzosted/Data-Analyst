# %% [markdown]
# OOPS
# - Object Oriented Programming
# - Objects allows us to model real world use cases

# %% [markdown]
# Module -> Pre-written code containing definitions of variables, functions, and classes.
#
# Package -> A collection/directory of related Python modules.

# %%
import math
math.sqrt(16)
# Out:
# 4.0

# %%
from math import sqrt
sqrt(25)
# Out:
# 5.0

# %%
from math import sqrt as s
s(36)
# Out:
# 6.0
